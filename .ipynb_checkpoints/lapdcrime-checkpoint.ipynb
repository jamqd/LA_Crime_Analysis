# %% [markdown]
# # Sike AI Challenge
#
# A Jupyter Notebook for Visualization of Crime Data in Los Angeles Since 2010
#
# Creator: John Dang

# %%
import pandas as pd
import tensorflow as tf
from keras.models import Model
import matplotlib as plt
import numpy as np
import geopandas as gp
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Read crime data into pandas dataframe
crime_df = pd.read_csv("Crime_Data_from_2010_to_Present.csv")

# %%
crime_df
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 0          1208575    03/14/2013    03/11/2013           1800       12
# 1        102005556    01/25/2010    01/22/2010           2300       20
# 2              418    03/19/2013    03/18/2013           2030       18
# 3        101822289    11/11/2010    11/10/2010           1800       18
# 4         42104479    01/11/2014    01/04/2014           2300       21
# 5        120125367    01/08/2013    01/08/2013           1400        1
# 6        101105609    01/28/2010    01/27/2010           2230       11
# 7        101620051    11/11/2010    11/07/2010           1600       16
# 8        101910498    04/07/2010    04/07/2010           1600       19
# 9        120908292    03/29/2013    01/15/2013            800        9
# 10       101927640    12/31/2010    12/30/2010           2100       19
# 11       101323794    10/26/2010    10/26/2010           1315       13
# ...

# %%
# List 21 LAPD divisions
crime_df["Area Name"].unique()
# Out:
# array(['77th Street', 'Olympic', 'Southeast', 'Topanga', 'Central',
#        'Northeast', 'Foothill', 'Mission', 'Van Nuys', 'Newton',
#        'N Hollywood', 'West Valley', 'Pacific', 'Devonshire', 'Rampart',
#        'Southwest', 'Hollenbeck', 'Harbor', 'Hollywood', 'West LA',
#        'Wilshire'], dtype=object)

# %% [markdown]
# # Data Analysis On West Los Angeles

# %%
# Create pandas dataframe of crime data in West Los Angeles
westLA_df = crime_df.loc[crime_df["Area Name"] == "West LA"]

# %%
westLA_df
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 43452    130600978    10/28/2013    10/24/2013           1800        8
# 54892    100812018    07/02/2010    07/02/2010           1620        8
# 56208    100811779    06/26/2010    06/26/2010           1700        8
# 57366    130809477    05/17/2013    05/17/2013           1545        8
# 57467    130810980    06/27/2013    06/27/2013            250        8
# 58436    100810214    05/21/2010    05/21/2010           1015        8
# 58983    130804185    01/05/2013    01/04/2013           1900        8
# 59003    130800505    01/03/2013    01/03/2013           1200        8
# 59004    130800510    01/04/2013    01/04/2013            730        8
# 59005    130800512    01/04/2013    01/04/2013           2050        8
# 59006    130800514    01/05/2013    01/04/2013           1400        8
# 59007    130800515    01/05/2013    01/05/2013            850        8
# ...

# %%
westLA_df.sample(500).plot.bar(x="Crime Code")

# %%
county_df = gp.read_file("DRP_COUNTY_BOUNDARY/DRP_COUNTY_BOUNDARY.shx")

# %%
county_df.head()
# Out:
#   LINE_TYPE     Shape_len                                           geometry
# 0     THICK  2.179389e+06  (LINESTRING (6384013.030082196 1468118.9098407...
# 1      THIN  5.306728e+05  (LINESTRING (6434100.799985185 1384515.6098560...

# %%
county_df.plot()

# %%
countyneigh_df = gp.read_file("la-county-neighborhoods-current/l.a. county neighborhood (current).shx")

# %%
countyneigh_df.head()
# Out:
#               slug                                  set  \
# 0            acton  L.A. County Neighborhoods (Current)
# 1  adams-normandie  L.A. County Neighborhoods (Current)
# 2     agoura-hills  L.A. County Neighborhoods (Current)
# 3       agua-dulce  L.A. County Neighborhoods (Current)
# 4         alhambra  L.A. County Neighborhoods (Current)
#
#                                  kind       external_i             name  \
# 0  L.A. County Neighborhood (Current)            acton            Acton
# 1  L.A. County Neighborhood (Current)  adams-normandie  Adams-Normandie
# 2  L.A. County Neighborhood (Current)     agoura-hills     Agoura Hills
# 3  L.A. County Neighborhood (Current)       agua-dulce       Agua Dulce
# 4  L.A. County Neighborhood (Current)         alhambra         Alhambra
#
#                                           display_na            sqmi  \
# 0           Acton L.A. County Neighborhood (Current)   39.3391089485
# ...

# %%
countyneigh_df.plot()

# %% [markdown]
# # Crime Occurrences in the last 10 Years in West Los Angeles

# %% [markdown]
# # Common Types of Crime in West Los Angeles

# %% [markdown]
# # Most Affected Age Groups

# %% [markdown]
# # Additional Insights
